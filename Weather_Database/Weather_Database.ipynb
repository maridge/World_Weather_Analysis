# %%
# Import the dependencies.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Create a set of latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 764

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | severo-kurilsk
# Processing Record 2 of Set 1 | henties bay
# Processing Record 3 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 1 | clyde river
# Processing Record 5 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 1 | bell ville
# Processing Record 7 of Set 1 | antofagasta
# Processing Record 8 of Set 1 | sao joao da barra
# Processing Record 9 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 1 | los llanos de aridane
# Processing Record 11 of Set 1 | hilo
# Processing Record 12 of Set 1 | dzhusaly
# City not found. Skipping...
# Processing Record 13 of Set 1 | vaini
# Processing Record 14 of Set 1 | hofn
# Processing Record 15 of Set 1 | atuona
# Processing Record 16 of Set 1 | kalmunai
# Processing Record 17 of Set 1 | beian
# Processing Record 18 of Set 1 | cap malheureux
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | carutapera
# Processing Record 21 of Set 1 | norman wells
# Processing Record 22 of Set 1 | khatanga
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | butaritari
# Processing Record 25 of Set 1 | mar del plata
# Processing Record 26 of Set 1 | vila
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | tual
# Processing Record 29 of Set 1 | broome
# Processing Record 30 of Set 1 | mirnyy
# Processing Record 31 of Set 1 | longyearbyen
# Processing Record 32 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 1 | bandundu
# Processing Record 34 of Set 1 | rikitea
# Processing Record 35 of Set 1 | albany
# Processing Record 36 of Set 1 | swakopmund
# Processing Record 37 of Set 1 | kapaa
# Processing Record 38 of Set 1 | busselton
# Processing Record 39 of Set 1 | asau
# Processing Record 40 of Set 1 | presidencia roque saenz pena
# Processing Record 41 of Set 1 | ahipara
# Processing Record 42 of Set 1 | port alfred
# Processing Record 43 of Set 1 | njeru
# Processing Record 44 of Set 1 | bredasdorp
# Processing Record 45 of Set 1 | hualmay
# Processing Record 46 of Set 1 | tarakan
# Processing Record 47 of Set 1 | vardo
# Processing Record 48 of Set 1 | samalaeulu
# City not found. Skipping...
# Processing Record 49 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 1 | sampit
# Processing Record 1 of Set 2 | bluff
# Processing Record 2 of Set 2 | kununurra
# Processing Record 3 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 2 | kodiak
# Processing Record 5 of Set 2 | taburi
# City not found. Skipping...
# Processing Record 6 of Set 2 | jamestown
# Processing Record 7 of Set 2 | srednekolymsk
# Processing Record 8 of Set 2 | krasnoselkup
# Processing Record 9 of Set 2 | sinnamary
# Processing Record 10 of Set 2 | honningsvag
# Processing Record 11 of Set 2 | ancud
# Processing Record 12 of Set 2 | portales
# Processing Record 13 of Set 2 | batemans bay
# Processing Record 14 of Set 2 | fort saint john
# City not found. Skipping...
# Processing Record 15 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 2 | ponta do sol
# Processing Record 17 of Set 2 | castro
# Processing Record 18 of Set 2 | hermanus
# Processing Record 19 of Set 2 | qaanaaq
# Processing Record 20 of Set 2 | polson
# Processing Record 21 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 2 | hobart
# Processing Record 23 of Set 2 | wanning
# Processing Record 24 of Set 2 | dicabisagan
# Processing Record 25 of Set 2 | vestbygda
# City not found. Skipping...
# Processing Record 26 of Set 2 | pangnirtung
# Processing Record 27 of Set 2 | northam
# Processing Record 28 of Set 2 | ushtobe
# Processing Record 29 of Set 2 | camp springs
# Processing Record 30 of Set 2 | uarini
# Processing Record 31 of Set 2 | buritizeiro
# Processing Record 32 of Set 2 | zaraza
# Processing Record 33 of Set 2 | tasiilaq
# Processing Record 34 of Set 2 | portobelo
# Processing Record 35 of Set 2 | chumikan
# Processing Record 36 of Set 2 | newport
# Processing Record 37 of Set 2 | basoko
# Processing Record 38 of Set 2 | leningradskiy
# Processing Record 39 of Set 2 | puerto ayora
# Processing Record 40 of Set 2 | phan rang
# City not found. Skipping...
# Processing Record 41 of Set 2 | avarua
# Processing Record 42 of Set 2 | lubango
# Processing Record 43 of Set 2 | georgetown
# Processing Record 44 of Set 2 | greenwood
# Processing Record 45 of Set 2 | alofi
# Processing Record 46 of Set 2 | bati
# Processing Record 47 of Set 2 | shelburne
# Processing Record 48 of Set 2 | upernavik
# Processing Record 49 of Set 2 | prince george
# Processing Record 50 of Set 2 | yarega
# Processing Record 1 of Set 3 | tiksi
# Processing Record 2 of Set 3 | uniontown
# Processing Record 3 of Set 3 | provideniya
# Processing Record 4 of Set 3 | ritchie
# Processing Record 5 of Set 3 | campestre
# Processing Record 6 of Set 3 | mahebourg
# Processing Record 7 of Set 3 | ampanihy
# Processing Record 8 of Set 3 | port elizabeth
# Processing Record 9 of Set 3 | kruisfontein
# Processing Record 10 of Set 3 | meulaboh
# Processing Record 11 of Set 3 | evensk
# Processing Record 12 of Set 3 | kegayli
# City not found. Skipping...
# Processing Record 13 of Set 3 | yinchuan
# Processing Record 14 of Set 3 | shimoda
# Processing Record 15 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 16 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 3 | barrow
# Processing Record 18 of Set 3 | mareeba
# Processing Record 19 of Set 3 | hithadhoo
# Processing Record 20 of Set 3 | daxian
# City not found. Skipping...
# Processing Record 21 of Set 3 | ilulissat
# Processing Record 22 of Set 3 | xiamen
# Processing Record 23 of Set 3 | oranjemund
# Processing Record 24 of Set 3 | matagami
# Processing Record 25 of Set 3 | nichinan
# Processing Record 26 of Set 3 | sisimiut
# Processing Record 27 of Set 3 | bathsheba
# Processing Record 28 of Set 3 | dve mogili
# Processing Record 29 of Set 3 | cape town
# Processing Record 30 of Set 3 | saint-pierre
# Processing Record 31 of Set 3 | san felipe
# Processing Record 32 of Set 3 | chuy
# Processing Record 33 of Set 3 | lasa
# Processing Record 34 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 35 of Set 3 | palestine
# Processing Record 36 of Set 3 | torbay
# Processing Record 37 of Set 3 | dikson
# Processing Record 38 of Set 3 | warrnambool
# Processing Record 39 of Set 3 | arraial do cabo
# Processing Record 40 of Set 3 | luderitz
# Processing Record 41 of Set 3 | port blair
# Processing Record 42 of Set 3 | sambava
# Processing Record 43 of Set 3 | lokosovo
# Processing Record 44 of Set 3 | opuwo
# Processing Record 45 of Set 3 | andros town
# Processing Record 46 of Set 3 | cherskiy
# Processing Record 47 of Set 3 | karabanovo
# Processing Record 48 of Set 3 | lebu
# Processing Record 49 of Set 3 | porto novo
# Processing Record 50 of Set 3 | khuzhir
# Processing Record 1 of Set 4 | walvis bay
# Processing Record 2 of Set 4 | pascagoula
# Processing Record 3 of Set 4 | chokurdakh
# Processing Record 4 of Set 4 | bambous virieux
# Processing Record 5 of Set 4 | champerico
# Processing Record 6 of Set 4 | saldanha
# Processing Record 7 of Set 4 | lavrentiya
# Processing Record 8 of Set 4 | beira
# Processing Record 9 of Set 4 | fortuna
# Processing Record 10 of Set 4 | fatehgarh churian
# Processing Record 11 of Set 4 | zhigansk
# Processing Record 12 of Set 4 | hornepayne
# Processing Record 13 of Set 4 | saskylakh
# Processing Record 14 of Set 4 | namatanai
# Processing Record 15 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 4 | tuatapere
# Processing Record 17 of Set 4 | yellowknife
# Processing Record 18 of Set 4 | uwayl
# City not found. Skipping...
# Processing Record 19 of Set 4 | goderich
# Processing Record 20 of Set 4 | vao
# Processing Record 21 of Set 4 | santiago del estero
# Processing Record 22 of Set 4 | labuhan
# Processing Record 23 of Set 4 | solnechnyy
# Processing Record 24 of Set 4 | wenling
# Processing Record 25 of Set 4 | bontang
# Processing Record 26 of Set 4 | uyar
# Processing Record 27 of Set 4 | east london
# Processing Record 28 of Set 4 | saint george
# Processing Record 29 of Set 4 | padang
# Processing Record 30 of Set 4 | blackwater
# Processing Record 31 of Set 4 | yarada
# Processing Record 32 of Set 4 | nyaunglebin
# Processing Record 33 of Set 4 | ribeira grande
# Processing Record 34 of Set 4 | san juan
# Processing Record 35 of Set 4 | praya
# Processing Record 36 of Set 4 | agadez
# Processing Record 37 of Set 4 | sitka
# Processing Record 38 of Set 4 | augusto correa
# Processing Record 39 of Set 4 | anadyr
# Processing Record 40 of Set 4 | salacgriva
# Processing Record 41 of Set 4 | deputatskiy
# Processing Record 42 of Set 4 | mount pleasant
# Processing Record 43 of Set 4 | bengkulu
# Processing Record 44 of Set 4 | puerto carreno
# Processing Record 45 of Set 4 | kaitangata
# Processing Record 46 of Set 4 | sawankhalok
# Processing Record 47 of Set 4 | marsala
# Processing Record 48 of Set 4 | odesskoye
# Processing Record 49 of Set 4 | zeya
# Processing Record 50 of Set 4 | thompson
# Processing Record 1 of Set 5 | coruripe
# Processing Record 2 of Set 5 | mogadishu
# Processing Record 3 of Set 5 | alzamay
# Processing Record 4 of Set 5 | bria
# Processing Record 5 of Set 5 | hasaki
# Processing Record 6 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 5 | tabou
# Processing Record 8 of Set 5 | paamiut
# Processing Record 9 of Set 5 | predejane
# Processing Record 10 of Set 5 | skibbereen
# Processing Record 11 of Set 5 | shenkursk
# Processing Record 12 of Set 5 | proddatur
# Processing Record 13 of Set 5 | lorengau
# Processing Record 14 of Set 5 | tuktoyaktuk
# Processing Record 15 of Set 5 | cheuskiny
# City not found. Skipping...
# Processing Record 16 of Set 5 | kenai
# Processing Record 17 of Set 5 | gushikawa
# Processing Record 18 of Set 5 | wulanhaote
# City not found. Skipping...
# Processing Record 19 of Set 5 | fasa
# Processing Record 20 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 21 of Set 5 | palatka
# Processing Record 22 of Set 5 | turayf
# Processing Record 23 of Set 5 | portland
# Processing Record 24 of Set 5 | kilindoni
# Processing Record 25 of Set 5 | yar-sale
# Processing Record 26 of Set 5 | sobolevo
# Processing Record 27 of Set 5 | aitape
# Processing Record 28 of Set 5 | esperance
# Processing Record 29 of Set 5 | narsaq
# Processing Record 30 of Set 5 | hanamaki
# Processing Record 31 of Set 5 | saint-philippe
# Processing Record 32 of Set 5 | isangel
# Processing Record 33 of Set 5 | deer lake
# Processing Record 34 of Set 5 | nesna
# Processing Record 35 of Set 5 | acapulco
# Processing Record 36 of Set 5 | farso
# Processing Record 37 of Set 5 | meiganga
# Processing Record 38 of Set 5 | vila franca do campo
# Processing Record 39 of Set 5 | ketchikan
# Processing Record 40 of Set 5 | ekhabi
# Processing Record 41 of Set 5 | souillac
# Processing Record 42 of Set 5 | richards bay
# Processing Record 43 of Set 5 | knyaze-volkonskoye
# Processing Record 44 of Set 5 | qianjiang
# Processing Record 45 of Set 5 | mandalgovi
# Processing Record 46 of Set 5 | new norfolk
# Processing Record 47 of Set 5 | buala
# Processing Record 48 of Set 5 | pavullo nel frignano
# Processing Record 49 of Set 5 | san francisco del mar
# Processing Record 50 of Set 5 | geraldton
# Processing Record 1 of Set 6 | kismayo
# Processing Record 2 of Set 6 | nalobikha
# Processing Record 3 of Set 6 | porto santo
# Processing Record 4 of Set 6 | maues
# Processing Record 5 of Set 6 | loja
# Processing Record 6 of Set 6 | san cristobal
# Processing Record 7 of Set 6 | aquiraz
# Processing Record 8 of Set 6 | muros
# Processing Record 9 of Set 6 | marrakesh
# Processing Record 10 of Set 6 | carberry
# Processing Record 11 of Set 6 | dunedin
# Processing Record 12 of Set 6 | smithers
# Processing Record 13 of Set 6 | lompoc
# Processing Record 14 of Set 6 | pevek
# Processing Record 15 of Set 6 | klaksvik
# Processing Record 16 of Set 6 | bow island
# Processing Record 17 of Set 6 | pemba
# Processing Record 18 of Set 6 | damara
# Processing Record 19 of Set 6 | benguela
# Processing Record 20 of Set 6 | tasbuget
# City not found. Skipping...
# Processing Record 21 of Set 6 | yulara
# Processing Record 22 of Set 6 | qaqortoq
# Processing Record 23 of Set 6 | morondava
# Processing Record 24 of Set 6 | ishikawa
# Processing Record 25 of Set 6 | port-cartier
# Processing Record 26 of Set 6 | luganville
# Processing Record 27 of Set 6 | borlange
# City not found. Skipping...
# Processing Record 28 of Set 6 | winslow
# Processing Record 29 of Set 6 | sohag
# Processing Record 30 of Set 6 | clearwater
# Processing Record 31 of Set 6 | salta
# Processing Record 32 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 33 of Set 6 | palencia
# Processing Record 34 of Set 6 | kasongo
# Processing Record 35 of Set 6 | broken hill
# Processing Record 36 of Set 6 | zhuozhou
# City not found. Skipping...
# Processing Record 37 of Set 6 | cabedelo
# Processing Record 38 of Set 6 | marsh harbour
# Processing Record 39 of Set 6 | chanika
# Processing Record 40 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 41 of Set 6 | freeport
# Processing Record 42 of Set 6 | sorland
# Processing Record 43 of Set 6 | jutai
# Processing Record 44 of Set 6 | san ramon
# Processing Record 45 of Set 6 | ponta delgada
# Processing Record 46 of Set 6 | namibe
# Processing Record 47 of Set 6 | warangal
# Processing Record 48 of Set 6 | palaikastron
# Processing Record 49 of Set 6 | coetupo
# City not found. Skipping...
# Processing Record 50 of Set 6 | lagoa
# Processing Record 1 of Set 7 | bethel
# Processing Record 2 of Set 7 | gazanjyk
# Processing Record 3 of Set 7 | aklavik
# Processing Record 4 of Set 7 | iaciara
# Processing Record 5 of Set 7 | brownsville
# Processing Record 6 of Set 7 | nome
# Processing Record 7 of Set 7 | sao gabriel da cachoeira
# Processing Record 8 of Set 7 | kavieng
# Processing Record 9 of Set 7 | kholm-zhirkovskiy
# Processing Record 10 of Set 7 | pemberton
# Processing Record 11 of Set 7 | la asuncion
# Processing Record 12 of Set 7 | faanui
# Processing Record 13 of Set 7 | airai
# Processing Record 14 of Set 7 | boende
# Processing Record 15 of Set 7 | hokitika
# Processing Record 16 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 7 | jinchang
# Processing Record 18 of Set 7 | sheopur
# Processing Record 19 of Set 7 | carnarvon
# Processing Record 20 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 21 of Set 7 | kharitonovo
# Processing Record 22 of Set 7 | aripuana
# Processing Record 23 of Set 7 | atocha
# Processing Record 24 of Set 7 | sao filipe
# Processing Record 25 of Set 7 | inirida
# Processing Record 26 of Set 7 | nikolskoye
# Processing Record 27 of Set 7 | caravelas
# Processing Record 28 of Set 7 | martil
# Processing Record 29 of Set 7 | campbell river
# Processing Record 30 of Set 7 | rehoboth
# Processing Record 31 of Set 7 | emerald
# Processing Record 32 of Set 7 | vallenar
# Processing Record 33 of Set 7 | avera
# Processing Record 34 of Set 7 | the woodlands
# Processing Record 35 of Set 7 | guerrero negro
# Processing Record 36 of Set 7 | novobelokatay
# Processing Record 37 of Set 7 | kiama
# Processing Record 38 of Set 7 | goure
# Processing Record 39 of Set 7 | fredericton
# Processing Record 40 of Set 7 | iqaluit
# Processing Record 41 of Set 7 | gat
# Processing Record 42 of Set 7 | asfi
# Processing Record 43 of Set 7 | dingle
# Processing Record 44 of Set 7 | osa
# Processing Record 45 of Set 7 | cururupu
# Processing Record 46 of Set 7 | mporokoso
# Processing Record 47 of Set 7 | awjilah
# Processing Record 48 of Set 7 | ust-tsilma
# Processing Record 49 of Set 7 | shenjiamen
# Processing Record 50 of Set 7 | victoria
# Processing Record 1 of Set 8 | gonen
# Processing Record 2 of Set 8 | kumta
# Processing Record 3 of Set 8 | ningan
# City not found. Skipping...
# Processing Record 4 of Set 8 | villafranca de los barros
# Processing Record 5 of Set 8 | aktas
# Processing Record 6 of Set 8 | belaya gora
# Processing Record 7 of Set 8 | milford
# Processing Record 8 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 9 of Set 8 | kargil
# Processing Record 10 of Set 8 | herouville-saint-clair
# Processing Record 11 of Set 8 | baykit
# Processing Record 12 of Set 8 | belmonte
# Processing Record 13 of Set 8 | beringovskiy
# Processing Record 14 of Set 8 | trairi
# Processing Record 15 of Set 8 | half moon bay
# Processing Record 16 of Set 8 | preeceville
# Processing Record 17 of Set 8 | poum
# Processing Record 18 of Set 8 | blythe
# Processing Record 19 of Set 8 | salinopolis
# Processing Record 20 of Set 8 | roma
# Processing Record 21 of Set 8 | nemuro
# Processing Record 22 of Set 8 | nador
# Processing Record 23 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 24 of Set 8 | san miguel
# Processing Record 25 of Set 8 | turukhansk
# Processing Record 26 of Set 8 | bogorodskoye
# Processing Record 27 of Set 8 | lima
# Processing Record 28 of Set 8 | honolulu
# Processing Record 29 of Set 8 | mogadouro
# Processing Record 30 of Set 8 | lamlash
# Processing Record 31 of Set 8 | san fernando
# Processing Record 32 of Set 8 | the valley
# Processing Record 33 of Set 8 | antalaha
# Processing Record 34 of Set 8 | port lincoln
# Processing Record 35 of Set 8 | stonewall
# Processing Record 36 of Set 8 | mbanza-ngungu
# Processing Record 37 of Set 8 | bulgan
# Processing Record 38 of Set 8 | jasper
# Processing Record 39 of Set 8 | sandeid
# Processing Record 40 of Set 8 | kargasok
# Processing Record 41 of Set 8 | port macquarie
# Processing Record 42 of Set 8 | kahului
# Processing Record 43 of Set 8 | pacific grove
# Processing Record 44 of Set 8 | barashevo
# Processing Record 45 of Set 8 | oum hadjer
# Processing Record 46 of Set 8 | iracoubo
# Processing Record 47 of Set 8 | selizharovo
# Processing Record 48 of Set 8 | arak
# Processing Record 49 of Set 8 | hay river
# Processing Record 50 of Set 8 | daloa
# Processing Record 1 of Set 9 | santa cruz
# Processing Record 2 of Set 9 | huarmey
# Processing Record 3 of Set 9 | la paz
# Processing Record 4 of Set 9 | jilib
# Processing Record 5 of Set 9 | victoria point
# Processing Record 6 of Set 9 | hambantota
# Processing Record 7 of Set 9 | merauke
# Processing Record 8 of Set 9 | sabha
# Processing Record 9 of Set 9 | cabo rojo
# Processing Record 10 of Set 9 | tucuman
# Processing Record 11 of Set 9 | ranot
# Processing Record 12 of Set 9 | verkhnyaya inta
# Processing Record 13 of Set 9 | faya
# Processing Record 14 of Set 9 | lazi
# Processing Record 15 of Set 9 | la rioja
# Processing Record 16 of Set 9 | korla
# Processing Record 17 of Set 9 | zarate
# Processing Record 18 of Set 9 | castelbuono
# Processing Record 19 of Set 9 | hamilton
# Processing Record 20 of Set 9 | leeton
# Processing Record 21 of Set 9 | balimo
# City not found. Skipping...
# Processing Record 22 of Set 9 | almaznyy
# Processing Record 23 of Set 9 | solovetskiy
# City not found. Skipping...
# Processing Record 24 of Set 9 | nizhniy kuranakh
# Processing Record 25 of Set 9 | sokolskoye
# Processing Record 26 of Set 9 | vila velha
# Processing Record 27 of Set 9 | gunjur
# Processing Record 28 of Set 9 | ukiah
# Processing Record 29 of Set 9 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 30 of Set 9 | hit
# Processing Record 31 of Set 9 | manokwari
# Processing Record 32 of Set 9 | autopan
# City not found. Skipping...
# Processing Record 33 of Set 9 | awbari
# Processing Record 34 of Set 9 | nantucket
# Processing Record 35 of Set 9 | felidhoo
# City not found. Skipping...
# Processing Record 36 of Set 9 | camacha
# Processing Record 37 of Set 9 | tsabong
# Processing Record 38 of Set 9 | idrinskoye
# Processing Record 39 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 40 of Set 9 | guaruja
# Processing Record 41 of Set 9 | inhambane
# Processing Record 42 of Set 9 | rio gallegos
# Processing Record 43 of Set 9 | limaong
# Processing Record 44 of Set 9 | olafsvik
# Processing Record 45 of Set 9 | solsvik
# City not found. Skipping...
# Processing Record 46 of Set 9 | shkotovo-26
# City not found. Skipping...
# Processing Record 47 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 48 of Set 9 | arlit
# Processing Record 49 of Set 9 | marawi
# Processing Record 50 of Set 9 | husavik
# Processing Record 1 of Set 10 | casablanca
# Processing Record 2 of Set 10 | tir pol
# City not found. Skipping...
# Processing Record 3 of Set 10 | cabo san lucas
# Processing Record 4 of Set 10 | palu
# Processing Record 5 of Set 10 | roura
# Processing Record 6 of Set 10 | nova olinda do norte
# Processing Record 7 of Set 10 | saint-denis
# Processing Record 8 of Set 10 | bocas del toro
# Processing Record 9 of Set 10 | brae
# Processing Record 10 of Set 10 | zagora
# Processing Record 11 of Set 10 | sakakah
# Processing Record 12 of Set 10 | ovalle
# Processing Record 13 of Set 10 | salalah
# Processing Record 14 of Set 10 | skjervoy
# Processing Record 15 of Set 10 | cidreira
# Processing Record 16 of Set 10 | mollendo
# Processing Record 17 of Set 10 | dukat
# Processing Record 18 of Set 10 | tazmalt
# Processing Record 19 of Set 10 | emba
# Processing Record 20 of Set 10 | sundsvall
# Processing Record 21 of Set 10 | killam
# Processing Record 22 of Set 10 | touros
# Processing Record 23 of Set 10 | mokhsogollokh
# Processing Record 24 of Set 10 | darnetal
# Processing Record 25 of Set 10 | oussouye
# Processing Record 26 of Set 10 | kirakira
# Processing Record 27 of Set 10 | timmins
# Processing Record 28 of Set 10 | coihaique
# Processing Record 29 of Set 10 | rocha
# Processing Record 30 of Set 10 | tezu
# Processing Record 31 of Set 10 | dawson creek
# Processing Record 32 of Set 10 | tingrela
# City not found. Skipping...
# Processing Record 33 of Set 10 | lyuban
# Processing Record 34 of Set 10 | adelaide
# Processing Record 35 of Set 10 | katsuura
# Processing Record 36 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 37 of Set 10 | rongcheng
# Processing Record 38 of Set 10 | rio cuarto
# Processing Record 39 of Set 10 | kailua
# Processing Record 40 of Set 10 | chapais
# Processing Record 41 of Set 10 | mattru
# Processing Record 42 of Set 10 | yomou
# Processing Record 43 of Set 10 | kavaratti
# Processing Record 44 of Set 10 | coquimbo
# Processing Record 45 of Set 10 | robe
# Processing Record 46 of Set 10 | key biscayne
# Processing Record 47 of Set 10 | olinda
# Processing Record 48 of Set 10 | ambulu
# Processing Record 49 of Set 10 | jennings
# Processing Record 50 of Set 10 | kandrian
# Processing Record 1 of Set 11 | elbistan
# Processing Record 2 of Set 11 | ciudad guayana
# Processing Record 3 of Set 11 | bitung
# Processing Record 4 of Set 11 | bom jesus
# Processing Record 5 of Set 11 | tucuru
# Processing Record 6 of Set 11 | datong
# Processing Record 7 of Set 11 | hoa binh
# Processing Record 8 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 9 of Set 11 | rio grande
# Processing Record 10 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 11 of Set 11 | chengam
# Processing Record 12 of Set 11 | adolfo lopez mateos
# Processing Record 13 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 14 of Set 11 | las cruces
# Processing Record 15 of Set 11 | kincardine
# Processing Record 16 of Set 11 | san patricio
# Processing Record 17 of Set 11 | mount gambier
# Processing Record 18 of Set 11 | fenoarivo atsinanana
# Processing Record 19 of Set 11 | kaputa
# Processing Record 20 of Set 11 | talas
# Processing Record 21 of Set 11 | ust-kuyga
# Processing Record 22 of Set 11 | ust-nera
# Processing Record 23 of Set 11 | cayenne
# Processing Record 24 of Set 11 | stornoway
# Processing Record 25 of Set 11 | jalingo
# Processing Record 26 of Set 11 | flinders
# Processing Record 27 of Set 11 | quatre cocos
# Processing Record 28 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 29 of Set 11 | saryshagan
# City not found. Skipping...
# Processing Record 30 of Set 11 | sorong
# Processing Record 31 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 32 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 11 | havelock
# Processing Record 34 of Set 11 | aykhal
# Processing Record 35 of Set 11 | boda
# Processing Record 36 of Set 11 | katherine
# Processing Record 37 of Set 11 | jiuquan
# Processing Record 38 of Set 11 | ivanovo
# Processing Record 39 of Set 11 | paciran
# Processing Record 40 of Set 11 | oktyabrskiy
# Processing Record 41 of Set 11 | larsnes
# Processing Record 42 of Set 11 | maningrida
# Processing Record 43 of Set 11 | komsomolskiy
# Processing Record 44 of Set 11 | tevaitoa
# Processing Record 45 of Set 11 | chara
# Processing Record 46 of Set 11 | nouakchott
# Processing Record 47 of Set 11 | ratoath
# Processing Record 48 of Set 11 | abbeville
# Processing Record 49 of Set 11 | bay city
# Processing Record 50 of Set 11 | luang prabang
# Processing Record 1 of Set 12 | doha
# Processing Record 2 of Set 12 | san luis obispo
# Processing Record 3 of Set 12 | honjo
# Processing Record 4 of Set 12 | sciacca
# Processing Record 5 of Set 12 | carpentersville
# Processing Record 6 of Set 12 | cartagena
# Processing Record 7 of Set 12 | sucua
# Processing Record 8 of Set 12 | wad madani
# Processing Record 9 of Set 12 | kabanjahe
# Processing Record 10 of Set 12 | garowe
# Processing Record 11 of Set 12 | lichinga
# Processing Record 12 of Set 12 | sioux lookout
# Processing Record 13 of Set 12 | halifax
# Processing Record 14 of Set 12 | diamantino
# Processing Record 15 of Set 12 | jining
# Processing Record 16 of Set 12 | college
# Processing Record 17 of Set 12 | nortelandia
# Processing Record 18 of Set 12 | grandola
# Processing Record 19 of Set 12 | tiznit
# Processing Record 20 of Set 12 | victor harbor
# Processing Record 21 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 22 of Set 12 | watsa
# Processing Record 23 of Set 12 | tilichiki
# Processing Record 24 of Set 12 | niimi
# Processing Record 25 of Set 12 | chifeng
# Processing Record 26 of Set 12 | port hardy
# Processing Record 27 of Set 12 | balkhash
# Processing Record 28 of Set 12 | pisco
# Processing Record 29 of Set 12 | cerro punta
# Processing Record 30 of Set 12 | maloy
# Processing Record 31 of Set 12 | la ronge
# Processing Record 32 of Set 12 | ulaangom
# Processing Record 33 of Set 12 | goma
# Processing Record 34 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 35 of Set 12 | esna
# Processing Record 36 of Set 12 | abu samrah
# Processing Record 37 of Set 12 | zhangjiakou
# Processing Record 38 of Set 12 | bairiki
# Processing Record 39 of Set 12 | rong kwang
# Processing Record 40 of Set 12 | samagaltay
# Processing Record 41 of Set 12 | praia da vitoria
# Processing Record 42 of Set 12 | mangai
# Processing Record 43 of Set 12 | marystown
# Processing Record 44 of Set 12 | haines junction
# Processing Record 45 of Set 12 | goya
# Processing Record 46 of Set 12 | pochutla
# Processing Record 47 of Set 12 | comodoro rivadavia
# Processing Record 48 of Set 12 | mount isa
# Processing Record 49 of Set 12 | westport
# Processing Record 50 of Set 12 | bijawar
# Processing Record 1 of Set 13 | zaykovo
# Processing Record 2 of Set 13 | sandwick
# Processing Record 3 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 4 of Set 13 | miraflores
# Processing Record 5 of Set 13 | nabire
# Processing Record 6 of Set 13 | atar
# Processing Record 7 of Set 13 | gemena
# Processing Record 8 of Set 13 | gorontalo
# Processing Record 9 of Set 13 | hof
# Processing Record 10 of Set 13 | saint-joseph
# Processing Record 11 of Set 13 | west wendover
# Processing Record 12 of Set 13 | beneditinos
# Processing Record 13 of Set 13 | lazaro cardenas
# Processing Record 14 of Set 13 | denpasar
# Processing Record 15 of Set 13 | bilibino
# Processing Record 16 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set 13 | dengzhou
# Processing Record 18 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 19 of Set 13 | uryupinsk
# Processing Record 20 of Set 13 | ixtapa
# Processing Record 21 of Set 13 | manacapuru
# Processing Record 22 of Set 13 | kemijarvi
# Processing Record 23 of Set 13 | kosa
# Processing Record 24 of Set 13 | dauphin
# Processing Record 25 of Set 13 | mayumba
# Processing Record 26 of Set 13 | aborlan
# Processing Record 27 of Set 13 | vicente guerrero
# Processing Record 28 of Set 13 | makat
# Processing Record 29 of Set 13 | cockburn town
# Processing Record 30 of Set 13 | makakilo city
# Processing Record 31 of Set 13 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 13 | athmallik
# Processing Record 33 of Set 13 | yanan
# City not found. Skipping...
# Processing Record 34 of Set 13 | zolotinka
# City not found. Skipping...
# Processing Record 35 of Set 13 | aswan
# Processing Record 36 of Set 13 | dhidhdhoo
# Processing Record 37 of Set 13 | ndioum
# Processing Record 38 of Set 13 | codrington
# Processing Record 39 of Set 13 | ostrovnoy
# Processing Record 40 of Set 13 | paka
# Processing Record 41 of Set 13 | talnakh
# Processing Record 42 of Set 13 | waipawa
# Processing Record 43 of Set 13 | berdigestyakh
# Processing Record 44 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 45 of Set 13 | angoche
# Processing Record 46 of Set 13 | shubarkuduk
# Processing Record 47 of Set 13 | nouadhibou
# Processing Record 48 of Set 13 | alikovo
# Processing Record 49 of Set 13 | jibuti
# Processing Record 50 of Set 13 | blackfoot
# Processing Record 1 of Set 14 | baturaja
# Processing Record 2 of Set 14 | paita
# Processing Record 3 of Set 14 | keene
# Processing Record 4 of Set 14 | necochea
# Processing Record 5 of Set 14 | esso
# Processing Record 6 of Set 14 | montrose
# Processing Record 7 of Set 14 | waseca
# Processing Record 8 of Set 14 | tutoia
# Processing Record 9 of Set 14 | chicama
# Processing Record 10 of Set 14 | sokoto
# Processing Record 11 of Set 14 | yumen
# Processing Record 12 of Set 14 | tomatlan
# Processing Record 13 of Set 14 | dombas
# Processing Record 14 of Set 14 | riyadh
# Processing Record 15 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 16 of Set 14 | saint anthony
# Processing Record 17 of Set 14 | cocal
# Processing Record 18 of Set 14 | anloga
# Processing Record 19 of Set 14 | port hedland
# Processing Record 20 of Set 14 | prieska
# Processing Record 21 of Set 14 | jiangyou
# Processing Record 22 of Set 14 | alta floresta
# Processing Record 23 of Set 14 | berlevag
# Processing Record 24 of Set 14 | seryshevo
# Processing Record 25 of Set 14 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 14 | brookings
# Processing Record 27 of Set 14 | miyako
# Processing Record 28 of Set 14 | mahadday weyne
# City not found. Skipping...
# Processing Record 29 of Set 14 | fremont
# Processing Record 30 of Set 14 | kamaishi
# Processing Record 31 of Set 14 | manohar thana
# Processing Record 32 of Set 14 | linqiong
# Processing Record 33 of Set 14 | mersing
# Processing Record 34 of Set 14 | zhongxing
# Processing Record 35 of Set 14 | novikovo
# Processing Record 36 of Set 14 | dujuma
# City not found. Skipping...
# Processing Record 37 of Set 14 | walla walla
# Processing Record 38 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 14 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 40 of Set 14 | kota tinggi
# Processing Record 41 of Set 14 | dekar
# Processing Record 42 of Set 14 | barranca
# Processing Record 43 of Set 14 | gazni
# City not found. Skipping...
# Processing Record 44 of Set 14 | puerto del rosario
# Processing Record 45 of Set 14 | curumani
# Processing Record 46 of Set 14 | belaya
# Processing Record 47 of Set 14 | bagtic
# Processing Record 48 of Set 14 | ariquemes
# Processing Record 49 of Set 14 | biltine
# Processing Record 50 of Set 14 | khor
# Processing Record 1 of Set 15 | garoua boulai
# Processing Record 2 of Set 15 | dwarka
# Processing Record 3 of Set 15 | fort nelson
# Processing Record 4 of Set 15 | pinega
# Processing Record 5 of Set 15 | naples
# Processing Record 6 of Set 15 | san lawrenz
# Processing Record 7 of Set 15 | luena
# Processing Record 8 of Set 15 | mastic beach
# Processing Record 9 of Set 15 | nanortalik
# Processing Record 10 of Set 15 | kristiansund
# Processing Record 11 of Set 15 | vanavara
# Processing Record 12 of Set 15 | del rio
# Processing Record 13 of Set 15 | itoman
# Processing Record 14 of Set 15 | astoria
# Processing Record 15 of Set 15 | minna
# Processing Record 16 of Set 15 | prince rupert
# Processing Record 17 of Set 15 | huicungo
# Processing Record 18 of Set 15 | qasigiannguit
# Processing Record 19 of Set 15 | okhotsk
# Processing Record 20 of Set 15 | chernyshevskiy
# Processing Record 21 of Set 15 | ouadda
# Processing Record 22 of Set 15 | eirunepe
# Processing Record 23 of Set 15 | moose factory
# Processing Record 24 of Set 15 | charcas
# Processing Record 25 of Set 15 | garchitorena
# Processing Record 26 of Set 15 | sulya
# Processing Record 27 of Set 15 | os
# City not found. Skipping...
# Processing Record 28 of Set 15 | caxias
# Processing Record 29 of Set 15 | okha
# Processing Record 30 of Set 15 | lakatoro
# Processing Record 31 of Set 15 | zharkent
# Processing Record 32 of Set 15 | tongliao
# Processing Record 33 of Set 15 | smirnykh
# Processing Record 34 of Set 15 | kudahuvadhoo
# Processing Record 35 of Set 15 | maniitsoq
# Processing Record 36 of Set 15 | wanlaweyn
# Processing Record 37 of Set 15 | sumbawa
# City not found. Skipping...
# Processing Record 38 of Set 15 | nuuk
# Processing Record 39 of Set 15 | boden
# Processing Record 40 of Set 15 | blagoevgrad
# Processing Record 41 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 42 of Set 15 | tarudant
# City not found. Skipping...
# Processing Record 43 of Set 15 | barahona
# Processing Record 44 of Set 15 | nkhata bay
# Processing Record 45 of Set 15 | bardiyah
# Processing Record 46 of Set 15 | imbituba
# Processing Record 47 of Set 15 | leh
# Processing Record 48 of Set 15 | yibin
# Processing Record 49 of Set 15 | icod de los vinos
# Processing Record 50 of Set 15 | energeticheskiy
# Processing Record 1 of Set 16 | buariki
# City not found. Skipping...
# Processing Record 2 of Set 16 | rorvik
# Processing Record 3 of Set 16 | kutahya
# Processing Record 4 of Set 16 | grand gaube
# Processing Record 5 of Set 16 | pangai
# Processing Record 6 of Set 16 | cocobeach
# Processing Record 7 of Set 16 | pakxan
# Processing Record 8 of Set 16 | carndonagh
# Processing Record 9 of Set 16 | biysk
# Processing Record 10 of Set 16 | aleppo
# Processing Record 11 of Set 16 | aljezur
# Processing Record 12 of Set 16 | sechura
# Processing Record 13 of Set 16 | kozhva
# Processing Record 14 of Set 16 | kimberley
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 688

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0    Severo-Kurilsk      RU  50.6789  156.1250     27.45        68
# 1       Henties Bay      NA -22.1160   14.2845     62.85        88
# 2       Clyde River      CA  70.4692  -68.5914     -8.54        75
# 3        Bell Ville      AR -32.6259  -62.6887     96.78        12
# 4       Antofagasta      CL -23.6500  -70.4000     69.60        75
# ..              ...     ...      ...       ...       ...       ...
# 683          Aleppo      SY  36.2500   37.5000     39.51        94
# 684         Aljezur      PT  37.3191   -8.8033     57.04        91
# 685         Sechura      PE  -5.5569  -80.8222     75.58        64
# 686          Kozhva      RU  65.1073   57.0459     -8.97        92
# 687       Kimberley      ZA -28.7323   24.7623     60.49        82
#
#      Cloudiness  Wind Speed Current Description                 Date
# 0            71       14.88       broken clouds  2021-12-23 22:07:24
# 1             0        5.79           clear sky  2021-12-23 22:07:25
# 2            80        4.25       broken clouds  2021-12-23 22:07:25
# 3             2        9.19           clear sky  2021-12-23 22:07:25
# 4            99        4.07     overcast clouds  2021-12-23 22:02:26
# ..          ...         ...                 ...                  ...
# 683         100        7.16     overcast clouds  2021-12-23 22:32:48
# 684         100        3.85     overcast clouds  2021-12-23 22:32:48
# 685          90       16.33     overcast clouds  2021-12-23 22:32:49
# 686          47        8.79    scattered clouds  2021-12-23 22:32:49
# 687          77        2.30       broken clouds  2021-12-23 22:32:49
#
# [688 rows x 10 columns]

# %%
# Reorder the columns.
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Assign a new or the same DataFrame.
city_data_df = city_data_df[new_column_order]

# %%
city_data_df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0    Severo-Kurilsk      RU  50.6789  156.1250     27.45        68
# 1       Henties Bay      NA -22.1160   14.2845     62.85        88
# 2       Clyde River      CA  70.4692  -68.5914     -8.54        75
# 3        Bell Ville      AR -32.6259  -62.6887     96.78        12
# 4       Antofagasta      CL -23.6500  -70.4000     69.60        75
# ..              ...     ...      ...       ...       ...       ...
# 683          Aleppo      SY  36.2500   37.5000     39.51        94
# 684         Aljezur      PT  37.3191   -8.8033     57.04        91
# 685         Sechura      PE  -5.5569  -80.8222     75.58        64
# 686          Kozhva      RU  65.1073   57.0459     -8.97        92
# 687       Kimberley      ZA -28.7323   24.7623     60.49        82
#
#      Cloudiness  Wind Speed Current Description
# 0            71       14.88       broken clouds
# 1             0        5.79           clear sky
# 2            80        4.25       broken clouds
# 3             2        9.19           clear sky
# 4            99        4.07     overcast clouds
# ..          ...         ...                 ...
# 683         100        7.16     overcast clouds
# 684         100        3.85     overcast clouds
# 685          90       16.33     overcast clouds
# 686          47        8.79    scattered clouds
# 687          77        2.30       broken clouds
#
# [688 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
